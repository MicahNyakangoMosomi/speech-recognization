# %%
import wave

# %%
obj = wave.open("./BAK.wav","rb")

# %%
print(obj.getparams())
# Out:
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=367538, comptype='NONE', compname='not compressed')

# %%
time = o
